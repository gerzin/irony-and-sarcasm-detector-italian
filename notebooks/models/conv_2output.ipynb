# %% [markdown]
# # Grid search

# %%
import sys
sys.path.append("../")

import itertools
import random
import pandas as pd
import numpy as np
from config import Config
import keras


VALIDATION_SPLIT = 0.1

# %%
from preprocessing.tokenizationWordVect import tokenize_frame
from keras.layers import Conv1D, Dropout, Flatten, Dense

# %%
level_1_Dropout = [0.5,0.2]
filters = [64, 32]
kernel_size = [5,3]
activation_conv = ['relu']
hidden_layers = [[(32,'relu',0.0),(16,'relu', 0.0)],[(32,'relu',0.1),(16,'relu', 0.1)],  [(24,'relu', 0.0)], [(24,'relu', 0.1)] ]
loss = ['mse']
epochs = [10, 20]


combinations = list(itertools.product(*[filters, kernel_size, activation_conv, level_1_Dropout, hidden_layers, loss, epochs]))
combinations



validation_performance = []

training_data = pd.read_csv(Config.TRAINING_DATASET_PATH)

from preprocessing.pipeline import ItalianTweetsPreprocessingPipeline
pp = ItalianTweetsPreprocessingPipeline()

preprocessed_training_data = pp.apply(training_data)

x = preprocessed_training_data['text']
y_1 = list(preprocessed_training_data['irony'])
y_2 = list(preprocessed_training_data['sarcasm'])
y = list(zip(y_1, y_2))

x= tokenize_frame(x, "sostituisciTag")
x = np.asarray(x)

tmp = list(zip(x,y))
random.shuffle(tmp)
x, y = zip(*tmp)


validate_size = int(len(x)*VALIDATION_SPLIT)
x_train, x_validate = x[:-validate_size], x[-validate_size:]
x_train = np.asarray(x_train)
x_validate = np.asarray(x_validate)
y_train, y_validate = y[:-validate_size], y[-validate_size:]
y_train = np.asarray(y_train)
y_validate = np.asarray(y_validate)

# %%
results = []
index = 0
print("numero di combinazioni da testare " + str(len(combinations)))
for combination in combinations:
    print("index: " + str(index) + " Configurazione: " + str(combination))
    
    model = keras.models.Sequential()
    model.add(Conv1D(filters=combination[0], kernel_size=combination[1], activation=combination[2], input_shape=(65,128)))
    if(combination[3] != 0.0):
        model.add(Dropout(combination[3]))
    model.add(Flatten())
    for e in combination[4]:
        model.add(Dense(e[0], activation=e[1]))
        if(e[2] != 0.0):
            model.add(Dropout(e[2]))
    model.add(Dense(2, activation = 'sigmoid'))
    model.compile(loss=combination[5], optimizer="adam", metrics=['acc'])
    
    history = model.fit(x_train, y_train, epochs=combination[6], verbose=0)
    result = model.evaluate(x_validate, y_validate)
    results.append([combination, dict(zip(model.metrics_names, result))])
    index += 1
# Out:
# numero di combinazioni da testare 64
# index: 0 Configurazione: (64, 5, 'relu', 0.5, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 10)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2066 - acc: 0.9975
# index: 1 Configurazione: (64, 5, 'relu', 0.5, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 20)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2108 - acc: 0.9824
# index: 2 Configurazione: (64, 5, 'relu', 0.5, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 10)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2073 - acc: 1.0000
# index: 3 Configurazione: (64, 5, 'relu', 0.5, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 20)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2422 - acc: 1.0000
# index: 4 Configurazione: (64, 5, 'relu', 0.5, [(24, 'relu', 0.0)], 'mse', 10)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2015 - acc: 1.0000
# index: 5 Configurazione: (64, 5, 'relu', 0.5, [(24, 'relu', 0.0)], 'mse', 20)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2231 - acc: 0.9950
# index: 6 Configurazione: (64, 5, 'relu', 0.5, [(24, 'relu', 0.1)], 'mse', 10)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1927 - acc: 0.9924
# index: 7 Configurazione: (64, 5, 'relu', 0.5, [(24, 'relu', 0.1)], 'mse', 20)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2121 - acc: 0.9924
# index: 8 Configurazione: (64, 5, 'relu', 0.2, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 10)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2293 - acc: 1.0000
# index: 9 Configurazione: (64, 5, 'relu', 0.2, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 20)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2468 - acc: 0.9824
# index: 10 Configurazione: (64, 5, 'relu', 0.2, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 10)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2318 - acc: 1.0000
# index: 11 Configurazione: (64, 5, 'relu', 0.2, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 20)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2589 - acc: 0.9975
# index: 12 Configurazione: (64, 5, 'relu', 0.2, [(24, 'relu', 0.0)], 'mse', 10)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2155 - acc: 0.9975
# index: 13 Configurazione: (64, 5, 'relu', 0.2, [(24, 'relu', 0.0)], 'mse', 20)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2281 - acc: 0.9975
# index: 14 Configurazione: (64, 5, 'relu', 0.2, [(24, 'relu', 0.1)], 'mse', 10)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2133 - acc: 1.0000
# index: 15 Configurazione: (64, 5, 'relu', 0.2, [(24, 'relu', 0.1)], 'mse', 20)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2337 - acc: 0.9723
# index: 16 Configurazione: (64, 3, 'relu', 0.5, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 10)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2127 - acc: 1.0000
# index: 17 Configurazione: (64, 3, 'relu', 0.5, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 20)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2109 - acc: 0.9924
# index: 18 Configurazione: (64, 3, 'relu', 0.5, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 10)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2030 - acc: 1.0000
# index: 19 Configurazione: (64, 3, 'relu', 0.5, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 20)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2078 - acc: 1.0000
# index: 20 Configurazione: (64, 3, 'relu', 0.5, [(24, 'relu', 0.0)], 'mse', 10)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1958 - acc: 0.9975
# index: 21 Configurazione: (64, 3, 'relu', 0.5, [(24, 'relu', 0.0)], 'mse', 20)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2016 - acc: 0.9924
# index: 22 Configurazione: (64, 3, 'relu', 0.5, [(24, 'relu', 0.1)], 'mse', 10)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1920 - acc: 1.0000
# index: 23 Configurazione: (64, 3, 'relu', 0.5, [(24, 'relu', 0.1)], 'mse', 20)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2028 - acc: 1.0000
# index: 24 Configurazione: (64, 3, 'relu', 0.2, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 10)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2186 - acc: 0.9773
# index: 25 Configurazione: (64, 3, 'relu', 0.2, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 20)
# 13/13 [==============================] - 0s 3ms/step - loss: 0.2439 - acc: 0.9698
# index: 26 Configurazione: (64, 3, 'relu', 0.2, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 10)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2098 - acc: 1.0000
# index: 27 Configurazione: (64, 3, 'relu', 0.2, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 20)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2508 - acc: 0.9975
# index: 28 Configurazione: (64, 3, 'relu', 0.2, [(24, 'relu', 0.0)], 'mse', 10)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2065 - acc: 0.9849
# index: 29 Configurazione: (64, 3, 'relu', 0.2, [(24, 'relu', 0.0)], 'mse', 20)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2247 - acc: 0.9924
# index: 30 Configurazione: (64, 3, 'relu', 0.2, [(24, 'relu', 0.1)], 'mse', 10)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2037 - acc: 0.9975
# index: 31 Configurazione: (64, 3, 'relu', 0.2, [(24, 'relu', 0.1)], 'mse', 20)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2243 - acc: 0.9950
# index: 32 Configurazione: (32, 5, 'relu', 0.5, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 10)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1978 - acc: 1.0000
# index: 33 Configurazione: (32, 5, 'relu', 0.5, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 20)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2042 - acc: 1.0000
# index: 34 Configurazione: (32, 5, 'relu', 0.5, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 10)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2009 - acc: 1.0000
# index: 35 Configurazione: (32, 5, 'relu', 0.5, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 20)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2134 - acc: 1.0000
# index: 36 Configurazione: (32, 5, 'relu', 0.5, [(24, 'relu', 0.0)], 'mse', 10)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1868 - acc: 0.9950
# index: 37 Configurazione: (32, 5, 'relu', 0.5, [(24, 'relu', 0.0)], 'mse', 20)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2182 - acc: 1.0000
# index: 38 Configurazione: (32, 5, 'relu', 0.5, [(24, 'relu', 0.1)], 'mse', 10)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1874 - acc: 0.9950
# index: 39 Configurazione: (32, 5, 'relu', 0.5, [(24, 'relu', 0.1)], 'mse', 20)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2078 - acc: 1.0000
# index: 40 Configurazione: (32, 5, 'relu', 0.2, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 10)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2193 - acc: 1.0000
# index: 41 Configurazione: (32, 5, 'relu', 0.2, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 20)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2319 - acc: 0.9849
# index: 42 Configurazione: (32, 5, 'relu', 0.2, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 10)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2231 - acc: 1.0000
# index: 43 Configurazione: (32, 5, 'relu', 0.2, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 20)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2504 - acc: 1.0000
# index: 44 Configurazione: (32, 5, 'relu', 0.2, [(24, 'relu', 0.0)], 'mse', 10)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2017 - acc: 0.9622
# index: 45 Configurazione: (32, 5, 'relu', 0.2, [(24, 'relu', 0.0)], 'mse', 20)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2276 - acc: 1.0000
# index: 46 Configurazione: (32, 5, 'relu', 0.2, [(24, 'relu', 0.1)], 'mse', 10)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1949 - acc: 0.9950
# index: 47 Configurazione: (32, 5, 'relu', 0.2, [(24, 'relu', 0.1)], 'mse', 20)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2204 - acc: 1.0000
# index: 48 Configurazione: (32, 3, 'relu', 0.5, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 10)
# 13/13 [==============================] - 0s 998us/step - loss: 0.1994 - acc: 0.9924
# index: 49 Configurazione: (32, 3, 'relu', 0.5, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 20)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2008 - acc: 1.0000
# index: 50 Configurazione: (32, 3, 'relu', 0.5, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 10)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1867 - acc: 1.0000
# index: 51 Configurazione: (32, 3, 'relu', 0.5, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 20)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2022 - acc: 1.0000
# index: 52 Configurazione: (32, 3, 'relu', 0.5, [(24, 'relu', 0.0)], 'mse', 10)
# 13/13 [==============================] - 0s 923us/step - loss: 0.1905 - acc: 1.0000
# index: 53 Configurazione: (32, 3, 'relu', 0.5, [(24, 'relu', 0.0)], 'mse', 20)
# 13/13 [==============================] - 0s 997us/step - loss: 0.1980 - acc: 0.9975
# index: 54 Configurazione: (32, 3, 'relu', 0.5, [(24, 'relu', 0.1)], 'mse', 10)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1928 - acc: 1.0000
# index: 55 Configurazione: (32, 3, 'relu', 0.5, [(24, 'relu', 0.1)], 'mse', 20)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1923 - acc: 1.0000
# index: 56 Configurazione: (32, 3, 'relu', 0.2, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 10)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2093 - acc: 0.9849
# index: 57 Configurazione: (32, 3, 'relu', 0.2, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 20)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2367 - acc: 0.9521
# index: 58 Configurazione: (32, 3, 'relu', 0.2, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 10)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1978 - acc: 1.0000
# index: 59 Configurazione: (32, 3, 'relu', 0.2, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 20)
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2392 - acc: 0.9924
# index: 60 Configurazione: (32, 3, 'relu', 0.2, [(24, 'relu', 0.0)], 'mse', 10)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2089 - acc: 0.9950
# index: 61 Configurazione: (32, 3, 'relu', 0.2, [(24, 'relu', 0.0)], 'mse', 20)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2228 - acc: 0.9723
# index: 62 Configurazione: (32, 3, 'relu', 0.2, [(24, 'relu', 0.1)], 'mse', 10)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1972 - acc: 1.0000
# index: 63 Configurazione: (32, 3, 'relu', 0.2, [(24, 'relu', 0.1)], 'mse', 20)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2173 - acc: 0.9899

# %%
metric = 'acc'
values = []


for i in range(len(results)):
    values.append((results[i][0],results[i][1][metric]))
                  
values.sort(key=lambda tup: tup[1], reverse = True)

print('Best Hyperparameter Configurations')
for v in values:
    print(v[0], v[1])
# Out:
# Best Hyperparameter Configurations
# (64, 5, 'relu', 0.5, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 10) 1.0
# (64, 5, 'relu', 0.5, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 20) 1.0
# (64, 5, 'relu', 0.5, [(24, 'relu', 0.0)], 'mse', 10) 1.0
# (64, 5, 'relu', 0.2, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 10) 1.0
# (64, 5, 'relu', 0.2, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 10) 1.0
# (64, 5, 'relu', 0.2, [(24, 'relu', 0.1)], 'mse', 10) 1.0
# (64, 3, 'relu', 0.5, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 10) 1.0
# (64, 3, 'relu', 0.5, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 10) 1.0
# (64, 3, 'relu', 0.5, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 20) 1.0
# (64, 3, 'relu', 0.5, [(24, 'relu', 0.1)], 'mse', 10) 1.0
# (64, 3, 'relu', 0.5, [(24, 'relu', 0.1)], 'mse', 20) 1.0
# (64, 3, 'relu', 0.2, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 10) 1.0
# (32, 5, 'relu', 0.5, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 10) 1.0
# (32, 5, 'relu', 0.5, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 20) 1.0
# (32, 5, 'relu', 0.5, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 10) 1.0
# (32, 5, 'relu', 0.5, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 20) 1.0
# (32, 5, 'relu', 0.5, [(24, 'relu', 0.0)], 'mse', 20) 1.0
# (32, 5, 'relu', 0.5, [(24, 'relu', 0.1)], 'mse', 20) 1.0
# (32, 5, 'relu', 0.2, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 10) 1.0
# (32, 5, 'relu', 0.2, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 10) 1.0
# (32, 5, 'relu', 0.2, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 20) 1.0
# (32, 5, 'relu', 0.2, [(24, 'relu', 0.0)], 'mse', 20) 1.0
# (32, 5, 'relu', 0.2, [(24, 'relu', 0.1)], 'mse', 20) 1.0
# (32, 3, 'relu', 0.5, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 20) 1.0
# (32, 3, 'relu', 0.5, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 10) 1.0
# (32, 3, 'relu', 0.5, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 20) 1.0
# (32, 3, 'relu', 0.5, [(24, 'relu', 0.0)], 'mse', 10) 1.0
# (32, 3, 'relu', 0.5, [(24, 'relu', 0.1)], 'mse', 10) 1.0
# (32, 3, 'relu', 0.5, [(24, 'relu', 0.1)], 'mse', 20) 1.0
# (32, 3, 'relu', 0.2, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 10) 1.0
# (32, 3, 'relu', 0.2, [(24, 'relu', 0.1)], 'mse', 10) 1.0
# (64, 5, 'relu', 0.5, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 10) 0.997481107711792
# (64, 5, 'relu', 0.2, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 20) 0.997481107711792
# (64, 5, 'relu', 0.2, [(24, 'relu', 0.0)], 'mse', 10) 0.997481107711792
# (64, 5, 'relu', 0.2, [(24, 'relu', 0.0)], 'mse', 20) 0.997481107711792
# (64, 3, 'relu', 0.5, [(24, 'relu', 0.0)], 'mse', 10) 0.997481107711792
# (64, 3, 'relu', 0.2, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 20) 0.997481107711792
# (64, 3, 'relu', 0.2, [(24, 'relu', 0.1)], 'mse', 10) 0.997481107711792
# (32, 3, 'relu', 0.5, [(24, 'relu', 0.0)], 'mse', 20) 0.997481107711792
# (64, 5, 'relu', 0.5, [(24, 'relu', 0.0)], 'mse', 20) 0.994962215423584
# (64, 3, 'relu', 0.2, [(24, 'relu', 0.1)], 'mse', 20) 0.994962215423584
# (32, 5, 'relu', 0.5, [(24, 'relu', 0.0)], 'mse', 10) 0.994962215423584
# (32, 5, 'relu', 0.5, [(24, 'relu', 0.1)], 'mse', 10) 0.994962215423584
# (32, 5, 'relu', 0.2, [(24, 'relu', 0.1)], 'mse', 10) 0.994962215423584
# (32, 3, 'relu', 0.2, [(24, 'relu', 0.0)], 'mse', 10) 0.994962215423584
# (64, 5, 'relu', 0.5, [(24, 'relu', 0.1)], 'mse', 10) 0.992443323135376
# (64, 5, 'relu', 0.5, [(24, 'relu', 0.1)], 'mse', 20) 0.992443323135376
# (64, 3, 'relu', 0.5, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 20) 0.992443323135376
# (64, 3, 'relu', 0.5, [(24, 'relu', 0.0)], 'mse', 20) 0.992443323135376
# (64, 3, 'relu', 0.2, [(24, 'relu', 0.0)], 'mse', 20) 0.992443323135376
# (32, 3, 'relu', 0.5, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 10) 0.992443323135376
# (32, 3, 'relu', 0.2, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 20) 0.992443323135376
# (32, 3, 'relu', 0.2, [(24, 'relu', 0.1)], 'mse', 20) 0.989924430847168
# (64, 3, 'relu', 0.2, [(24, 'relu', 0.0)], 'mse', 10) 0.984886646270752
# (32, 5, 'relu', 0.2, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 20) 0.984886646270752
# (32, 3, 'relu', 0.2, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 10) 0.984886646270752
# (64, 5, 'relu', 0.5, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 20) 0.982367753982544
# (64, 5, 'relu', 0.2, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 20) 0.982367753982544
# (64, 3, 'relu', 0.2, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 10) 0.9773299694061279
# (64, 5, 'relu', 0.2, [(24, 'relu', 0.1)], 'mse', 20) 0.9722921848297119
# (32, 3, 'relu', 0.2, [(24, 'relu', 0.0)], 'mse', 20) 0.9722921848297119
# (64, 3, 'relu', 0.2, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 20) 0.9697732925415039
# (32, 5, 'relu', 0.2, [(24, 'relu', 0.0)], 'mse', 10) 0.9622166156768799
# (32, 3, 'relu', 0.2, [(32, 'relu', 0.0), (16, 'relu', 0.0)], 'mse', 20) 0.9521410465240479

# %% [markdown]
# # Best Model

# %%
from pathlib import Path
import sys
sys.path.append("../")


from config import Config
import pandas as pd

# %%
training_data = pd.read_csv(Config.TRAINING_DATASET_PATH)
test_data = pd.read_csv(Config.TEST_DATASET_PATH)
del test_data['id']
del test_data['topic']

# %%
from preprocessing.pipeline import ItalianTweetsPreprocessingPipeline
pp = ItalianTweetsPreprocessingPipeline()

# %%
preprocessed_training_data = pp.apply(training_data)
preprocessed_test_data = pp.apply(test_data)

# %%
x_train = preprocessed_training_data['text']
x_test = preprocessed_test_data['text']
y_train = preprocessed_training_data[['irony','sarcasm']]
y_test = preprocessed_test_data[['irony','sarcasm']]

# %%
import keras
from keras.layers import Conv1D, Dense, Dropout, Flatten

import sklearn
import numpy as np
from custom_metrics import computeAvgF1, model_test_2out

from preprocessing.tokenizationWordVect import tokenize_frame
import numpy as np

VALIDATION_SIZE = 0.1

# %%
# Seed value
seed_value= 450

# 1. Set the `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set the `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set the `numpy` pseudo-random generator at a fixed value
import numpy as np
np.random.seed(seed_value)

# 4. Set the `tensorflow` pseudo-random generator at a fixed value
import tensorflow as tf
tf.random.set_seed(seed_value)
# for later versions: 
# tf.compat.v1.set_random_seed(seed_value)

# 5. Configure a new global `tensorflow` session
from keras import backend as K
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
K.set_session(sess)

# %%
def model_conv(x, y, combination):
    
    model = keras.models.Sequential()
    model.add(Conv1D(filters=combination[0], kernel_size=combination[1], activation=combination[2], input_shape=(65,128)))
    if(combination[3] != 0.0):
        model.add(Dropout(combination[3]))
    model.add(Flatten())
    for e in combination[4]:
        model.add(Dense(e[0], activation=e[1]))
        if(e[2] != 0.0):
            model.add(Dropout(e[2]))
    model.add(Dense(2, activation = 'sigmoid'))
    model.compile(loss=combination[5], optimizer="adam", metrics=['acc'])
    
    history = model.fit(x, y, epochs=combination[6], validation_split = VALIDATION_SIZE)
    
    
    return model

# %%
x_train_conv = tokenize_frame(x_train, "sostituisciTag")
x_train_conv = np.asarray(x_train_conv)

x_test_conv = tokenize_frame(x_test, "sostituisciTag")
x_test_conv = np.asarray(x_test_conv)

hyperparameters = [64, 5, 'relu', 0.5, [(32, 'relu', 0.1), (16, 'relu', 0.1)], 'mse', 10]
model = model_conv(x_train_conv, y_train, hyperparameters)

# %%
from custom_metrics import computePerformanceTaskB_2output

print("F1 Average Task A-B")
computePerformanceTaskB_2output(model, x_test_conv, y_test, y_test['irony'])
